# %% [markdown]
# # Analysing Car Dataset using Pandas

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# ### Load Dataset

# %%
car=pd.read_csv(r"car.csv")

# %% [markdown]
# ### Display the head of data

# %%
car.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# ### Display tail of Dataset

# %%
car.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# ###### Now I have looked into the data,now I need to know the data types and count of values in each column. This will help me to check which columns contain empty or null cells

# %%
# what is size of data
car.size
# Out:
# 190624

# %% [markdown]
# => what is shape( rows x columns) of data

# %%
car.shape
# Out:
# (11914, 16)

# %% [markdown]
# it means above data has 11914 rows. So any column having less than 11914 values will have null values.

# %% [markdown]
# ### Now, find which columns have null values i.e less than total rows

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %% [markdown]
# From above data we can easily see that  column numbers 3, 4, 5, 8 and 9 have null values

# %%
# How much null values each column has
car.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# ###### Drop null values of each column

# %%
car2=car.dropna()

# %%
car2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8084 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               8084 non-null   object
#  1   Model              8084 non-null   object
#  2   Year               8084 non-null   int64
#  3   Engine Fuel Type   8084 non-null   object
#  4   Engine HP          8084 non-null   float64
#  5   Engine Cylinders   8084 non-null   float64
#  6   Transmission Type  8084 non-null   object
#  7   Driven_Wheels      8084 non-null   object
#  8   Number of Doors    8084 non-null   float64
#  9   Market Category    8084 non-null   object
#  10  Vehicle Size       8084 non-null   object
#  11  Vehicle Style      8084 non-null   object
#  12  highway MPG        8084 non-null   int64
#  13  city mpg           8084 non-null   int64
#  14  Popularity         8084 non-null   int64
#  15  MSRP               8084 non-null   int64
# ...

# %%
car2.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# ###### Since our operation is successful i will apply changes to original file

# %%
car.dropna(inplace=True)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8084 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               8084 non-null   object
#  1   Model              8084 non-null   object
#  2   Year               8084 non-null   int64
#  3   Engine Fuel Type   8084 non-null   object
#  4   Engine HP          8084 non-null   float64
#  5   Engine Cylinders   8084 non-null   float64
#  6   Transmission Type  8084 non-null   object
#  7   Driven_Wheels      8084 non-null   object
#  8   Number of Doors    8084 non-null   float64
#  9   Market Category    8084 non-null   object
#  10  Vehicle Size       8084 non-null   object
#  11  Vehicle Style      8084 non-null   object
#  12  highway MPG        8084 non-null   int64
#  13  city mpg           8084 non-null   int64
#  14  Popularity         8084 non-null   int64
#  15  MSRP               8084 non-null   int64
# ...

# %% [markdown]
# ###### Duplicate rows

# %%
# Rows containing duplicate data
duplicate_rows_car = car[car.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_car.shape)
# Out:
# Number of duplicate rows:  (435, 10)

# %% [markdown]
# ###### Drop Duplicate rows

# %%
# Drop the duplicates 
car = car.drop_duplicates()
car.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price
# 0     26     19  46135
# 1     28     19  40650
# 2     28     20  36350
# 3     28     18  29450
# 4     28     18  34500

# %% [markdown]
# ### Descriptive Statistics

# %%
car.describe()
# Out:
#               Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  8084.000000  8084.000000       8084.000000      8084.000000
# mean   2012.058634   274.642751          5.778080         3.414151
# std       6.317981   115.003475          1.886088         0.898087
# min    1990.000000    55.000000          0.000000         2.000000
# 25%    2010.000000   192.000000          4.000000         2.000000
# 50%    2015.000000   264.000000          6.000000         4.000000
# 75%    2016.000000   320.000000          6.000000         4.000000
# max    2017.000000  1001.000000         16.000000         4.000000
#
#        highway MPG     city mpg   Popularity          MSRP
# count  8084.000000  8084.000000  8084.000000  8.084000e+03
# mean     26.650915    19.553686  1499.397823  5.007267e+04
# std       7.720473     7.159964  1413.855615  7.029313e+04
# min      12.000000     7.000000     2.000000  2.000000e+03
# 25%      22.000000    16.000000   549.000000  2.591875e+04
# ...

# %% [markdown]
# this data has only numerical columns but i wnat to have description of object columns too

# %%
# providing include='all' will give description of all the columns
car.describe(include='all')
# Out:
#              Make  Model         Year  Engine Fuel Type    Engine HP  \
# count        8084   8084  8084.000000              8084  8084.000000
# unique         47    713          NaN                 8          NaN
# top     Chevrolet  F-150          NaN  regular unleaded          NaN
# freq          614    122          NaN              3507          NaN
# mean          NaN    NaN  2012.058634               NaN   274.642751
# std           NaN    NaN     6.317981               NaN   115.003475
# min           NaN    NaN  1990.000000               NaN    55.000000
# 25%           NaN    NaN  2010.000000               NaN   192.000000
# 50%           NaN    NaN  2015.000000               NaN   264.000000
# 75%           NaN    NaN  2016.000000               NaN   320.000000
# max           NaN    NaN  2017.000000               NaN  1001.000000
#
#         Engine Cylinders Transmission Type      Driven_Wheels  \
# count        8084.000000              8084               8084
# ...

# %% [markdown]
# ###### Question: What are different manufacturer/Make and their counts?

# %%
car['Make'].value_counts()
# Out:
# Chevrolet        614
# Volkswagen       581
# Ford             492
# Cadillac         397
# Mercedes-Benz    352
# BMW              334
# Infiniti         330
# Audi             328
# Dodge            320
# Nissan           308
# Toyota           300
# Honda            282
# Volvo            281
# GMC              270
# Acura            252
# Mazda            239
# Subaru           214
# Hyundai          214
# Lexus            202
# Lincoln          156
# Land Rover       143
# Porsche          136
# Mitsubishi       125
# Buick            125
# Saab             111
# Kia              109
# Chrysler         108
# Suzuki            99
# Aston Martin      93
# Pontiac           77
# Bentley           74
# Ferrari           68
# Maserati          58
# Lamborghini       52
# Scion             48
# Plymouth          39
# FIAT              38
# Rolls-Royce       31
# Lotus             29
# HUMMER            17
# Maybach           16
# Alfa Romeo         5
# McLaren            5
# ...

# %% [markdown]
# ###### Question : Who is the top manufacturer?

# %%
car['Make'].describe().top
# Out:
# 'Chevrolet'

# %% [markdown]
# ###### Question : What is mostly used Model?

# %%
car['Model'].value_counts()
# Out:
# F-150             122
# Silverado 1500    114
# GTI                76
# Beetle             75
# Corvette           60
#                  ...
# LFA                 1
# Lancer              1
# Intrepid            1
# Horizon             1
# Zephyr              1
# Name: Model, Length: 713, dtype: int64

# %%
dict({car['Model'].describe().top : car['Model'].value_counts()[car['Model'].describe().top]})
# Out:
# {'F-150': 122}

# %% [markdown]
# ###### Question : Select all records having automatic transmission?

# %%
car.head(1)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135

# %%
car[car['Transmission Type']=='AUTOMATIC']
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 19        Audi     100  1992                regular unleaded      172.0
# 23        Audi     100  1993                regular unleaded      172.0
# 27        Audi     100  1994                regular unleaded      172.0
# 30        Audi     100  1994                regular unleaded      172.0
# 31        Audi     100  1994                regular unleaded      172.0
# ...        ...     ...   ...                             ...        ...
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
car[car['Transmission Type']=='MANUAL']
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11897  BMW          Z4  2015  premium unleaded (required)      240.0
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %% [markdown]
# ###### select data where  model is BMW,Audi

# %%
car['Make'].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'McLaren',
#        'Maybach', 'Porsche', 'Toyota', 'Saab', 'GMC', 'Hyundai', 'Honda',
#        'Cadillac', 'Bentley', 'Ford', 'Oldsmobile', 'Chevrolet', 'Dodge',
#        'Lamborghini', 'Lincoln', 'Pontiac', 'Subaru', 'Volkswagen',
#        'Spyker', 'Kia', 'Acura', 'Plymouth', 'Rolls-Royce', 'Maserati',
#        'Lexus', 'Aston Martin', 'Land Rover', 'Lotus', 'Buick',
#        'Infiniti', 'Scion', 'Genesis', 'Suzuki', 'HUMMER', 'Bugatti'],
#       dtype=object)

# %%
car[car['Make'].isin(['BMW','Audi'])]
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Histograms

# %% [markdown]
# ###### Histograms are plotted for numerical data columns. hist() function will plot histograms for all numerical columns

# %%
# total count for each category of each column
car.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Engine HP'}>,
#         <Axes: title={'center': 'Engine Cylinders'}>],
#        [<Axes: title={'center': 'Number of Doors'}>,
#         <Axes: title={'center': 'highway MPG'}>,
#         <Axes: title={'center': 'city mpg'}>],
#        [<Axes: title={'center': 'Popularity'}>,
#         <Axes: title={'center': 'MSRP'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ### BoxPlot

# %%
# Relationship between Vehicle Size and Engine HP variable
sns.boxplot(x="Vehicle Size", y="Engine HP", data = car)
# Out:
# <Axes: xlabel='Vehicle Size', ylabel='Engine HP'>

# %% [markdown]
# ### PairPlot

# %% [markdown]
# You can think of pairplot as cross product of plots

# %%
sns.pairplot(car)

# %%
# Drop irrelevant columns
car = car.drop(['Engine Fuel Type', 'Market Category', 'Vehicle Style', 'Popularity', 'Number of Doors', 'Vehicle Size'], axis=1)
car.head(5)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels  highway MPG  city mpg   MSRP
# 0  rear wheel drive           26        19  46135
# 1  rear wheel drive           28        19  40650
# 2  rear wheel drive           28        20  36350
# 3  rear wheel drive           28        18  29450
# 4  rear wheel drive           28        18  34500

# %%
# Renaming the column names
car = car.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
car.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price
# 0     26     19  46135
# 1     28     19  40650
# 2     28     20  36350
# 3     28     18  29450
# 4     28     18  34500

# %%
# Finding the outliers
sns.boxplot(x=car['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.boxplot(x=car['HP'])
# Out:
# <Axes: xlabel='HP'>

# %%
# Plotting a Histogram for number of cars per brand
car.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel("Number of cars")
plt.xlabel("Make");

# %%
# Find the relations between the variables.
plt.figure(figsize=(20,10))
c= car.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# C:\Users\Basit Hussain\AppData\Local\Temp\ipykernel_2876\212339999.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= car.corr()
#                Year        HP  Cylinders     MPG-H     MPG-C     Price
# Year       1.000000  0.215876  -0.072016  0.226398  0.189428  0.113378
# HP         0.215876  1.000000   0.810924 -0.470591 -0.512439  0.654034
# Cylinders -0.072016  0.810924   1.000000 -0.599947 -0.615133  0.588033
# MPG-H      0.226398 -0.470591  -0.599947  1.000000  0.817965 -0.256153
# MPG-C      0.189428 -0.512439  -0.615133  0.817965  1.000000 -0.266989
# Price      0.113378  0.654034   0.588033 -0.256153 -0.266989  1.000000
